# %% [markdown]
# # Генеровані білети

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 1
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо використаних боєприпасів за останні 17 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_185. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Сталь відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 2
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у танках за останні 21 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_297. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Сталь відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 3
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у обладнанні за останні 27 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_140. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Степ відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 4
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у обладнанні за останні 25 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_90. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Мундир відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 5
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у вантажівках за останні 24 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_77. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Грозове небо відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 6
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у бронетехніці за останні 13 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_139. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Сталь відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 7
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у вантажівках за останні 9 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_232. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Марун відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 8
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у артилерії за останні 20 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_89. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Мундир відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 9
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у бронетехніці за останні 7 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_158. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Грозове небо відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 10
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у танках за останні 24 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_63. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Олива відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 11
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у вантажівках за останні 12 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_60. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Мундир відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 12
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо використаних боєприпасів за останні 28 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_158. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Олива відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 13
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у бронетехніці за останні 26 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_231. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Марун відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 14
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у вантажівках за останні 7 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_245. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Олива відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 15
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у особовому складі за останні 27 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_102. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Марун відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 16
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у вантажівках за останні 24 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_78. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Олива відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 17
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у артилерії за останні 15 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_222. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Сталь відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 18
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо використаних боєприпасів за останні 16 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_202. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Грозове небо відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 19
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у танках за останні 14 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_79. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Степ відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).

# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 20
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо втрат противника у особовому складі за останні 10 днів на основі наданого [шаблону](https://github.com/RomanMykolaichuk/mi2024_exam.git).
#
# 1. База даних exam_38. Створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML
#    - CSS
#    - JavaScript
#
# 4. Кольорова схема має відповідати основному кольору Олива відповідно до [брендбуку ЗСУ](https://warbooks.com.ua/contents/brendbuk-зсу-керівництво-із-використання-графічного-стилю-у-візуальній-комунікації.pdf).
